# %% [markdown]
# ### Probability theory-1 [Homework]

# %% [markdown]
# **Note:**
#
# > Please do not remove comments or lines of code.
#
# > You can use the packages ```NumPy```, ```matplotlib```.
#
# > Please show your solution by writing the calculation procedure.
#
#
#
# **Dice:**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. Solve the questions related to probability theory given below:
#
# > We tossed the coin 1000 times and got ```Heads``` 488 times. Estimate the probability of receiving ```Tails```. Assign the result to the variable ```p_tails```.
#
# > We rolled the dice 200 times and got ```three``` 45 times. Estimate the probability of getting a ```three`` when throwing a die. Assign the result to the variable ```p_three```.
#
# > We rolled the dice 400 times and got the odd number ```(1, 3 or 5)``` 230 times. Estimate the probability of getting an odd number when throwing a die. Assign the result to the variable ```p_odd```.

# %%
#Начало вашего кода

#Конец вашего кода

print(f"{p_tails*100:.2f} %")
print(f"{p_three*100:.2f} %")
print(f"{p_odd*100:.2f} %")

# %% [markdown]
# ### Expected results:
#
# ```
# 51.20 %
# 22.50 %
# 57.50 %
# ```

# %% [markdown]
# 2. An insurance company conducted a study of 1,000 people and found that:
#
# a) 706 people chose at least a life insurance policy.
#
# b) 445 people chose at least life and car insurance policies.
#
# c) 75 people chose at least a home insurance policy.
#
# d) 913 people chose at least one type of insurance policy.
#
# We cannot predict people's choices with certainty. So you might assume that a person's choice of who to buy an insurance policy is a random experiment. The study involved 1,000 people, so the random experiment can be considered to have been performed 1,000 times. Find:
#
# * the probability that a person will choose at least life insurance. Assign the answer to the variable ```p_life```.
#
# * the probability that a person will choose at least life and car insurance policies. Assign the answer to the variable ```p_life_car```.
#
# * the probability that a person will choose at least a home insurance policy. Assign the answer to the variable ```p_house```.
#
# * the likelihood that a person will not have insurance at all. Assign the answer to the variable ```p_no```.

# %%
#Начало вашего кода

#Конец вашего кода

print(f"{p_life*100:.2f} %")
print(f"{p_life_car*100:.2f} %")
print(f"{p_house*100:.2f} %")
print(f"{p_no*100:.2f} %")

# %% [markdown]
# ### Expected results:
#
# ```
# 70.60 %
# 44.50 %
# 7.50 %
# 8.70 %
# ```

# %% [markdown]
# 3. Please simulate the experiments with a coin. Let's assume there is an equal chance of getting Heads and Tails after one coin toss. Estimate the probability of getting Tails if you flip a coin between 10 and 10,000 times. Figure size ```(7.5)``` and ```seed=1```
#
# You can visualize the simulation results like this:
#
# ### Expected results:
#
# ![image.png](attachment:image.png)

# %%
#Начало вашего кода
import matplotlib.pyplot as plt
import numpy as np
import numpy.random as rd
import numpy as np



# your code

xtick=np.arange(1000,11001,1000).tolist();
xtick.insert(0,10);
plt.xticks(xtick);
plt.xlim(10,10000);

plt.title('P(Tails)');
plt.xlabel('# of flips');
plt.ylabel('Probability of Tails');
plt.rcParams["legend.scatterpoints"]=5
plt.legend([main,theor],['Simulation','Theoretical']);

#Конец вашего кода

# %% [markdown]
# 4. Please simulate the experiments with dice (with sides ```{1,2,3,4,5,6}```). Let's assume that there is an equal chance of getting any of the six sides after throwing a die. Estimate the probability of getting a number less than or equal to 2 after rolling a die between 10 and 10,000 times. Figure size ```(7.5)``` and ```seed=1```
#
# You can visualize the simulation results like this:
#
# ### Expected results:
#
# ![image.png](attachment:image.png)

# %%
#Начало вашего кода



plt.title('P(<3)');
plt.xlabel('# of flips');
plt.ylabel('Probability');
plt.rcParams["legend.scatterpoints"]=5
plt.legend([main,theor],['Simulation','Theoretical']);
#Конец вашего кода

# %% [markdown]
# 5. Please simulate the experiments with dice (with sides ```{1,2,2,3,4,5}```). Let's assume that there is an equal chance of getting any of the six sides after throwing a die. Estimate the probability of getting a number less than or equal to 3 after rolling a die between 10 and 10,000 times. Figure size ```(7.5)``` and ```seed=1```
#
# You can visualize the simulation results like this:
#
# ### Expected results:
#
# ![image.png](attachment:image.png)

# %%
#Начало вашего кода


plt.title('P(<4)');
plt.xlabel('# of flips');
plt.ylabel('Probability of getting number <4');
plt.rcParams["legend.scatterpoints"]=5
plt.legend([main,theor],['Simulation','Theoretical']);
#Конец вашего кода

# %% [markdown]
# ### Great job
