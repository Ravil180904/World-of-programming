# %% [markdown]
# ### pandas: Working with strings! [Homework]
# > **You must import all required packages yourself.**
#
# > **Write code only where it is shown to be written. Don't delete comments!**

# %% [markdown]
# ### Step 1
#
# Please write a function ```load_data(filename)``` that will load data from a csv file into a list of lists. Please write a function ```load_data(filename)``` that will load data from a csv file into a ```DataFrame```. The file ```num_house_prices.csv``` is provided with this jupyter notebook.
#
#
# **Note:**
#
# * If the file name is incorrect, the ```load_data``` function should display the following error message:
#
# ```{имя файла} does not exist```
# * ```str_house_prices.csv``` - это csv-файл, который является результатом вашей предыдущей домашней работы.

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\dell\\Documents\\codes\\KBTU\\Intro_2_ML\\Seminar_work'

# %%
#Начало вашего кода
import pandas as pd

data = pd.read_csv('C:\\Users\\dell\\Documents\\codes\\Data2\\str_house_prices.csv')

#Конец вашего кода

# %%
print(data)
# Out:
#         Id MSZoning Street LotShape LandContour Utilities LotConfig LandSlope  \
# 0        1       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1        2       RL   Pave      Reg         Lvl    AllPub       FR2       Gtl
# 2        3       RL   Pave      IR1         Lvl    AllPub    Inside       Gtl
# 3        4       RL   Pave      IR1         Lvl    AllPub    Corner       Gtl
# 4        5       RL   Pave      IR1         Lvl    AllPub       FR2       Gtl
# ...    ...      ...    ...      ...         ...       ...       ...       ...
# 1333  1456       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1334  1457       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1335  1458       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1336  1459       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1337  1460       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
#
#      Neighborhood Condition1  ... Electrical KitchenQual Functional  \
# 0         CollgCr       Norm  ...      SBrkr          Gd        Typ
# 1         Veenker      Feedr  ...      SBrkr          TA        Typ
# 2         CollgCr       Norm  ...      SBrkr          Gd        Typ
# 3         Crawfor       Norm  ...      SBrkr          Gd        Typ
# 4         NoRidge       Norm  ...      SBrkr          Gd        Typ
# ...           ...        ...  ...        ...         ...        ...
# 1333      Gilbert       Norm  ...      SBrkr          TA        Typ
# 1334       NWAmes       Norm  ...      SBrkr          TA       Min1
# 1335      Crawfor       Norm  ...      SBrkr          Gd        Typ
# 1336        NAmes       Norm  ...      FuseA          Gd        Typ
# 1337      Edwards       Norm  ...      SBrkr          TA        Typ
#
#      GarageType GarageFinish GarageQual GarageCond PavedDrive SaleType  \
# 0        Attchd          RFn         TA         TA          Y       WD
# 1        Attchd          RFn         TA         TA          Y       WD
# 2        Attchd          RFn         TA         TA          Y       WD
# 3        Detchd          Unf         TA         TA          Y       WD
# 4        Attchd          RFn         TA         TA          Y       WD
# ...         ...          ...        ...        ...        ...      ...
# 1333     Attchd          RFn         TA         TA          Y       WD
# 1334     Attchd          Unf         TA         TA          Y       WD
# 1335     Attchd          RFn         TA         TA          Y       WD
# 1336     Attchd          Unf         TA         TA          Y       WD
# 1337     Attchd          Fin         TA         TA          Y       WD
#
#      SaleCondition
# 0           Normal
# 1           Normal
# 2           Normal
# 3          Abnorml
# 4           Normal
# ...            ...
# 1333        Normal
# 1334        Normal
# 1335        Normal
# 1336        Normal
# 1337        Normal
#
# [1338 rows x 39 columns]

# %%
print(data.columns.values.tolist())
# Out:
# ['Id', 'MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'SaleType', 'SaleCondition']

# %% [markdown]
# ### Ожидаемый результат:
#
# ```
# ['Id', 'MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'SaleType', 'SaleCondition']
# ```

# %%
data

# %% [markdown]
# **Распечатайте первые и последние 5 строк pandas.DataFrame:**

# %%
#Начало вашего кода
data.head(5)
#Конец вашего кода
# Out:
#    Id MSZoning Street LotShape LandContour Utilities LotConfig LandSlope  \
# 0   1       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1   2       RL   Pave      Reg         Lvl    AllPub       FR2       Gtl
# 2   3       RL   Pave      IR1         Lvl    AllPub    Inside       Gtl
# 3   4       RL   Pave      IR1         Lvl    AllPub    Corner       Gtl
# 4   5       RL   Pave      IR1         Lvl    AllPub       FR2       Gtl
#
#   Neighborhood Condition1  ... Electrical KitchenQual Functional GarageType  \
# 0      CollgCr       Norm  ...      SBrkr          Gd        Typ     Attchd
# 1      Veenker      Feedr  ...      SBrkr          TA        Typ     Attchd
# 2      CollgCr       Norm  ...      SBrkr          Gd        Typ     Attchd
# 3      Crawfor       Norm  ...      SBrkr          Gd        Typ     Detchd
# 4      NoRidge       Norm  ...      SBrkr          Gd        Typ     Attchd
#
#   GarageFinish GarageQual GarageCond PavedDrive SaleType SaleCondition
# 0          RFn         TA         TA          Y       WD        Normal
# 1          RFn         TA         TA          Y       WD        Normal
# 2          RFn         TA         TA          Y       WD        Normal
# 3          Unf         TA         TA          Y       WD       Abnorml
# 4          RFn         TA         TA          Y       WD        Normal
#
# [5 rows x 39 columns]

# %%
data.dtypes
# Out:
# Id                int64
# MSZoning         object
# Street           object
# LotShape         object
# LandContour      object
# Utilities        object
# LotConfig        object
# LandSlope        object
# Neighborhood     object
# Condition1       object
# Condition2       object
# BldgType         object
# HouseStyle       object
# RoofStyle        object
# RoofMatl         object
# Exterior1st      object
# Exterior2nd      object
# MasVnrType       object
# ExterQual        object
# ExterCond        object
# Foundation       object
# BsmtQual         object
# BsmtCond         object
# BsmtExposure     object
# BsmtFinType1     object
# BsmtFinType2     object
# Heating          object
# HeatingQC        object
# CentralAir       object
# Electrical       object
# KitchenQual      object
# Functional       object
# GarageType       object
# GarageFinish     object
# GarageQual       object
# GarageCond       object
# PavedDrive       object
# SaleType         object
# SaleCondition    object
# dtype: object

# %%
data['Street'].value_counts()
# Out:
# Pave    1333
# Grvl       5
# Name: Street, dtype: int64

# %%
data['Neighborhood'].value_counts(normalize= True)
# Out:
# NAmes      0.156203
# CollgCr    0.109118
# OldTown    0.074738
# Somerst    0.062033
# Gilbert    0.057549
# NridgHt    0.056054
# NWAmes     0.054559
# Edwards    0.052317
# Sawyer     0.051570
# SawyerW    0.039611
# Crawfor    0.037369
# BrkSide    0.035127
# Mitchel    0.031390
# NoRidge    0.030643
# Timber     0.027653
# IDOTRR     0.021674
# ClearCr    0.019432
# StoneBr    0.018685
# SWISU      0.014948
# Blmngtn    0.012706
# BrDale     0.011211
# MeadowV    0.008969
# Veenker    0.008221
# NPkVill    0.006726
# Blueste    0.001495
# Name: Neighborhood, dtype: float64

# %% [markdown]
# ### Ожидаемый результат:
#
# ```
# Id MSZoning Street LotShape LandContour Utilities LotConfig LandSlope  \
# 0   1       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1   2       RL   Pave      Reg         Lvl    AllPub       FR2       Gtl
# 2   3       RL   Pave      IR1         Lvl    AllPub    Inside       Gtl
# 3   4       RL   Pave      IR1         Lvl    AllPub    Corner       Gtl
# 4   5       RL   Pave      IR1         Lvl    AllPub       FR2       Gtl
#
# Neighborhood Condition1  ... Electrical KitchenQual Functional GarageType  \
# 0      CollgCr       Norm  ...      SBrkr          Gd        Typ     Attchd
# 1 Veenker Feedr ... SBrkr TA Type Attchd
# 2      CollgCr       Norm  ...      SBrkr          Gd        Typ     Attchd
# 3 Crawford Norma Brkr Gd Type Detached
# 4 NoRridge Normal Brkr Gd Type Attached
#
# GarageFinish GarageQual GarageCond PavedDrive SaleType SaleCondition
# 0          RFn         TA         TA          Y       WD        Normal
# 1          RFn         TA         TA          Y       WD        Normal
# 2          RFn         TA         TA          Y       WD        Normal
# 3 Unf TA TA Y WD Abnorml
# 4          RFn         TA         TA          Y       WD        Normal
#
# [5 rows x 39 columns]
# Id MSZoning Street LotShape LandContour Utilities LotConfig LandSlope  \
# 1333  1456       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1334  1457       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1335  1458       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1336  1459       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1337  1460       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
#
# Neighborhood Condition1  ... Electrical KitchenQual Functional  \
# 1333      Gilbert       Norm  ...      SBrkr          TA        Typ
# 1334 NWAmes Norm ... SBrkr TA Min1
# 1335 Crawford Normal Brkr Gd Type
# 1336        NAmes       Norm  ...      FuseA          Gd        Typ
# 1337      Edwards       Norm  ...      SBrkr          TA        Typ
#
# GarageType GarageFinish GarageQual GarageCond PavedDrive SaleType  \
# 1333 Attchd RFn TA TA Y WD
# 1334 Attchd Unf TA TA Y WD
# 1335 Attchd RFn TA TA Y WD
# 1336 Attchd Unf TA TA Y WD
# 1337 Attchd Fin TA TA Y WD
#
# SaleCondition
# 1333        Normal
# 1334        Normal
# 1335        Normal
# 1336        Normal
# 1337        Normal
#
# [5 rows x 39 columns]
# ```

# %% [markdown]
# ### Шаг 2
#
# Запустите приведенный ниже блок кода и попытайтесь получить представление о данных, которые вы просматриваете.

# %%
pd_data=data.copy()
pd_data.set_index("Id",inplace=True)
pd_data
# Out:
#      MSZoning Street LotShape LandContour Utilities LotConfig LandSlope  \
# Id
# 1          RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 2          RL   Pave      Reg         Lvl    AllPub       FR2       Gtl
# 3          RL   Pave      IR1         Lvl    AllPub    Inside       Gtl
# 4          RL   Pave      IR1         Lvl    AllPub    Corner       Gtl
# 5          RL   Pave      IR1         Lvl    AllPub       FR2       Gtl
# ...       ...    ...      ...         ...       ...       ...       ...
# 1456       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1457       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1458       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1459       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1460       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
#
#      Neighborhood Condition1 Condition2  ... Electrical KitchenQual  \
# Id                                       ...
# 1         CollgCr       Norm       Norm  ...      SBrkr          Gd
# 2         Veenker      Feedr       Norm  ...      SBrkr          TA
# 3         CollgCr       Norm       Norm  ...      SBrkr          Gd
# 4         Crawfor       Norm       Norm  ...      SBrkr          Gd
# 5         NoRidge       Norm       Norm  ...      SBrkr          Gd
# ...           ...        ...        ...  ...        ...         ...
# 1456      Gilbert       Norm       Norm  ...      SBrkr          TA
# 1457       NWAmes       Norm       Norm  ...      SBrkr          TA
# 1458      Crawfor       Norm       Norm  ...      SBrkr          Gd
# 1459        NAmes       Norm       Norm  ...      FuseA          Gd
# 1460      Edwards       Norm       Norm  ...      SBrkr          TA
#
#      Functional GarageType GarageFinish GarageQual GarageCond PavedDrive  \
# Id
# 1           Typ     Attchd          RFn         TA         TA          Y
# 2           Typ     Attchd          RFn         TA         TA          Y
# 3           Typ     Attchd          RFn         TA         TA          Y
# 4           Typ     Detchd          Unf         TA         TA          Y
# 5           Typ     Attchd          RFn         TA         TA          Y
# ...         ...        ...          ...        ...        ...        ...
# 1456        Typ     Attchd          RFn         TA         TA          Y
# 1457       Min1     Attchd          Unf         TA         TA          Y
# 1458        Typ     Attchd          RFn         TA         TA          Y
# 1459        Typ     Attchd          Unf         TA         TA          Y
# 1460        Typ     Attchd          Fin         TA         TA          Y
#
#      SaleType SaleCondition
# Id
# 1          WD        Normal
# 2          WD        Normal
# 3          WD        Normal
# 4          WD       Abnorml
# 5          WD        Normal
# ...       ...           ...
# 1456       WD        Normal
# 1457       WD        Normal
# 1458       WD        Normal
# 1459       WD        Normal
# 1460       WD        Normal
#
# [1338 rows x 38 columns]

# %% [markdown]
# Пожалуйста, реализуйте функцию ```count_by_group(data,column)```, которая возвращает статистику по группе ```column``` для столбца ```column``` в ```DataFrame```. Статистика содержит количество уникальных значений в столбце.

# %%
#Начало вашего кода
data['LotShape'].value_counts()
#Конец вашего кода
# Out:
# Reg    829
# IR1    459
# IR2     40
# IR3     10
# Name: LotShape, dtype: int64

# %%
result=count_by_group(data=pd_data,column="LotShape")
print(result)

# %% [markdown]
# ### Ожидаемый результат:
#
# ```
# LotShape
# IR1 459
# Sweat 40
# IRZ 10
# Reg    829
# Name: LotShape, dtype: int64
# ```

# %%
result=count_by_group(data=pd_data,column="")
print(type(result))
print(result)

# %% [markdown]
# ### Ожидаемый результат:
#
# ```
# <class 'dict'>
# {'MSZoning': RL         1066
# RM          191
# FV           62
# RH           11
# C (all)       8
# Name: MSZoning, dtype: int64, 'Street': Pave    1333
# Grvl       5
# Name: Street, dtype: int64, 'LotShape': Reg    829
# IR1 459
# Sweat 40
# IRZ 10
# Name: LotShape, dtype: int64, 'LandContour': Lvl    1206
# Bank 52
# HLS      48
# Low      32
# Name: LandContour, dtype: int64, 'Utilities': AllPub    1337
# NoSeWa 1
# Name: Utilities, dtype: int64, 'LotConfig': Inside     957
# Corner     244
# Cul DE Sac 90
# Difference 43
# FR3          4
# Name: LotConfig, dtype: int64, 'LandSlope': Gtl    1265
# Mod      61
# Sev      12
# Name: LandSlope, dtype: int64, 'Neighborhood': NAmes      209
# CollgCr 146
# Old Town 100
# Somerset 83
# Gilbert     77
# NridgHt     75
# NWAmes      73
# Edwards     70
# Sawyer      69
# SawyerW     53
# Crawford 50
# BrkSide 47
# Mitchel     42
# NoRidge     41
# Timber      37
# IDOTRR      29
# ClearCr     26
# StoneBr     25
# swiss 20
# Blmngtn 17
# BrDale      15
# MeadowV     12
# Veenker 11
# NPkVill      9
# Blueste      2
# Name: Neighborhood, dtype: int64, 'Condition1': Norm      1162
# Feedr       63
# Artery      43
# RRAn 26
# Posen 19
# RRA 10
# PosA 8
# RRNs 5
# RRNo 2
# Name: Condition1, dtype: int64, 'Condition2': Norm      1324
# Feedr        5
# Artery       2
# Posen 2
# RRNs 2
# PosA 1
# RRAn 1
# RRAe 1
# Name: Condition2, dtype: int64, 'BldgType': 1Fam      1138
# Tunhas 112
# He bit down
# Duplex      28
# 2fmCon      22
# Name: BldgType, dtype: int64, 'HouseStyle': 1Story    657
# 2Story    426
# 1. Khafan 134
# SLvl       64
# SFoyer     30
# 1.5Unf     11
# 2.5Unf     10
# A. Khafan i
# Name: HouseStyle, dtype: int64, 'RoofStyle': Gable      1037
# Hip         272
# Flat         11
# Gambrel      10
# Mansard 6
# Shed          2
# Name: RoofStyle, dtype: int64, 'RoofMatl': CompShg    1314
# Tar&Grv 9
# WdShngl       6
# WdShake       5
# Roll          1
# Membrane 1
# ClyTile       1
# Metal         1
# Name: RoofMatl, dtype: int64, 'Exterior1st': VinylSd    486
# HdBoard 211
# MetalSd    201
# Wd Sdng 183
# Plywood    100
# CemntBd 52
# BrkFace     44
# Stucco 21
# WdShing     20
# AsbShng     15
# Stone        2
# ImStucc 1
# BrkComm      1
# CBlock       1
# Name: Exterior1st, dtype: int64, 'Exterior2nd': VinylSd    475
# MetalSd    197
# HdBoard 197
# Wd Sdng 176
# Plywood    127
# CmentBd     51
# Wd Shng     32
# Stucco 23
# BrkFace     22
# AsbShng     16
# ImStucc 10
# Brk Cmn      6
# AsphShn      2
# Stone        2
# CBlock       1
# Other        1
# Name: Exterior2nd, dtype: int64, 'MasVnrType': None       763
# BrkFace    432
# Stone      128
# BrkCmn 15
# Name: MasVnrType, dtype: int64, 'ExterQual': TA    803
# Gd    477
# Ex     51
# Fa      7
# Name: ExterQual, dtype: int64, 'ExterCond': TA    1183
# Gd     137
# Fa      16
# Ex       2
# Name: ExterCond, dtype: int64, 'Foundation': PConc     620
# CBlock    580
# Practical 129
# Stone       6
# Wood        3
# Name: Foundation, dtype: int64, 'BsmtQual': TA    594
# Gd    592
# Ex    120
# Fa     32
# Name: BsmtQual, dtype: int64, 'BsmtCond': TA    1237
# Gd      62
# Fa      38
# After 1
# Name: BsmtCond, dtype: int64, 'BsmtExposure': No    887
# Out of 213
# Gd    127
# Mn    111
# Name: BsmtExposure, dtype: int64, 'BsmtFinType1': GLQ    402
# Unf    392
# ALQ 209
# SHIT 141
# Rec    125
# Luke knock
# Name: BsmtFinType1, dtype: int64, 'BsmtFinType2': Unf    1176
# Rec      53
# Luke 46
# DAMN 32
# ALQ 19
# LOOK 12
# Name: BsmtFinType2, dtype: int64, 'Heating': GasA    1318
# GasW 16
# Grav       3
# OTHO 1
# Name: Heating, dtype: int64, 'HeatingQC': Ex    704
# TA 380
# Gd    217
# Fa     36
# After 1
# Name: HeatingQC, dtype: int64, 'CentralAir': Y    1277
# N      61
# Name: CentralAir, dtype: int64, 'Electrical': SBrkr    1242
# Fusea 76
# FuseF      17
# FuseP       2
# Mix         1
# Name: Electrical, dtype: int64, 'KitchenQual': TA    650
# Gd    568
# Ex     97
# Fa     23
# Name: KitchenQual, dtype: int64, 'Functional': Typ     1254
# We have 30
# Min1 28
# Mod       11
# May 1 10
# Coming 4
# Sev        1
# Name: Functional, dtype: int64, 'GarageType': Attchd     852
# Detchd 369
# BuiltIn     85
# Basement 19
# CarPort      7
# 2Types       6
# Name: GarageType, dtype: int64, 'GarageFinish': Unf    580
# RFn 413
# Fin    345
# Name: GarageFinish, dtype: int64, 'GarageQual': TA    1270
# Fa      48
# Gd      14
# After 3
# Ex       3
# Name: GarageQual, dtype: int64, 'GarageCond': TA    1287
# Fa      33
# Gd       9
# After 7
# Ex       2
# Name: GarageCond, dtype: int64, 'PavedDrive': Y    1257
# N      54
# P      27
# Name: PavedDrive, dtype: int64, 'SaleType': WD       1158
# New       117
# COD        42
# ConLD 6
# ConLw 4
# ConLI 4
# CWD         4
# Con         2
# Oth         1
# Name: SaleType, dtype: int64, 'SaleCondition': Normal     1104
# Partial     120
# Abnorml      86
# Family       20
# Alloca 7
# AdjCountry 1
# Name: SaleCondition, dtype: int64}
# ```

# %% [markdown]
# ### Шаг 3
#
# Вам даны данные ```dirty_str_house_prices.csv```. Ваша цель - очистить их, используя методы, предоставляемые ```pandas```, такие как ```DataFrame.apply()```, ```DataFrame.str.lower()``` и т. д. Все не алфавитно-цифровые символы можно считать шумом.
#
# **Пожалуйста, будьте осторожны при изучении данных.**

# %%
data['Neighborhood'].apply(lambda x: x[:1])
# Out:
# 0       C
# 1       V
# 2       C
# 3       C
# 4       N
#        ..
# 1333    G
# 1334    N
# 1335    C
# 1336    N
# 1337    E
# Name: Neighborhood, Length: 1338, dtype: object

# %%
data['MSZoning'].apply(lambda x: x.capitalize())
# Out:
# 0       Rl
# 1       Rl
# 2       Rl
# 3       Rl
# 4       Rl
#         ..
# 1333    Rl
# 1334    Rl
# 1335    Rl
# 1336    Rl
# 1337    Rl
# Name: MSZoning, Length: 1338, dtype: object

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data[data['Neighborhood'] == 'Veenker'][['Id','MSZoning','Street','LotShape']].sort_values('LotShape').plot()

#. Вытащить первые 4 колонок где Neighbourghood = 'Veenker'
#2. Нужно отсортировать по LotShape
# Out:
# <AxesSubplot:>

# %%
data.sort_values('Neighborhood')
# Out:
#         Id MSZoning Street LotShape LandContour Utilities LotConfig LandSlope  \
# 198    220       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1277  1395       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 425    466       RM   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 899    983       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 919   1005       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# ...    ...      ...    ...      ...         ...       ...       ...       ...
# 1065  1165       RL   Pave      IR1         Lvl    AllPub       FR2       Gtl
# 1146  1254       RL   Pave      IR1         Lvl    AllPub    Inside       Gtl
# 1        2       RL   Pave      Reg         Lvl    AllPub       FR2       Gtl
# 613    673       RL   Pave      IR1         Lvl    AllPub    Inside       Gtl
# 144    161       RL   Pave      IR1         Lvl    AllPub   CulDSac       Gtl
#
#      Neighborhood Condition1  ... Electrical KitchenQual Functional  \
# 198       Blmngtn       Norm  ...      SBrkr          Gd        Typ
# 1277      Blmngtn       Norm  ...      SBrkr          Gd        Typ
# 425       Blmngtn       Norm  ...      SBrkr          Gd        Typ
# 899       Blmngtn       Norm  ...      SBrkr          Gd        Typ
# 919       Blmngtn       Norm  ...      SBrkr          Gd        Typ
# ...           ...        ...  ...        ...         ...        ...
# 1065      Veenker      Feedr  ...      SBrkr          Gd        Typ
# 1146      Veenker       Norm  ...      SBrkr          Gd        Typ
# 1         Veenker      Feedr  ...      SBrkr          TA        Typ
# 613       Veenker       Norm  ...      SBrkr          TA        Typ
# 144       Veenker       Norm  ...      SBrkr          TA        Typ
#
#      GarageType GarageFinish GarageQual GarageCond PavedDrive SaleType  \
# 198      Attchd          Fin         TA         TA          Y      New
# 1277     Attchd          Fin         TA         TA          Y      New
# 425      Attchd          Fin         TA         TA          Y       WD
# 899      Attchd          Fin         TA         TA          Y       WD
# 919      Attchd          Fin         TA         TA          Y       WD
# ...         ...          ...        ...        ...        ...      ...
# 1065     Attchd          Unf         TA         TA          Y       WD
# 1146     Attchd          RFn         TA         TA          Y       WD
# 1        Attchd          RFn         TA         TA          Y       WD
# 613      Attchd          RFn         TA         TA          Y       WD
# 144      Attchd          Unf         TA         TA          Y       WD
#
#      SaleCondition
# 198        Partial
# 1277       Partial
# 425         Normal
# 899         Normal
# 919         Normal
# ...            ...
# 1065        Normal
# 1146        Normal
# 1           Normal
# 613         Normal
# 144         Normal
#
# [1338 rows x 39 columns]

# %%
#Начало вашего кода

#Конец вашего кода
print(dirty_data)

# %% [markdown]
# ### Ожидаемый результат:
#
# ```
# MSZoning  Street LotShape LandContour Utilities   LotConfig LandSlope  \
# Id
# 1         rl:   PAVE.     ;REg       \tlvl   AllPub.     InsidE:      gtl
# 2       ...RL   <PAVE    reg\t        Lvl;  AllPUb\t        FR2       Gtl<
# 3        ;Rl    Pave      ir1?        LVL!   Allpub!    ?inside     ...Gtl
# 4          rl   pave.     ;IR1        .Lvl  ;ALLPUB;     >Corner      ;GTL
# 5       .rl\t  PaVE\t   Ir1...        Lvl<   !Allpub        ?fr2   .GTL...
# ...       ...     ...      ...         ...       ...         ...       ...
# 1456      ?rl   PAVE>   ...Reg       >LVL<  Allpub\t  ...INSIDe:      GTL;
# 1457      Rl<   <PAVE      REG      ...lvl   Allpub:     .INsIDE      Gtl.
# 1458      ?RL   Pave!   ...Reg        >LVL   AlLPUb.     !InSiDE      >GTl
# 1459     RL\t   PAvE<     reg;      ?lvl\t   .AlLPUb     Inside:      :Gtl
# 1460     .rl!  <Pave:     Reg;     ...LVL?  .AlLPUb      INsIDe.    gtl...
#
# Neighborhood Condition1 Condition2  ... Electrical KitchenQual  \
# Id                                       ...
# 1        COLLGCR<      norm;      NORM.  ...     SBRKr         gd\t
# 2 veenker\t ?FEedr. ;norm ... \tSBRKR to?
# 3        ?COLLGCR      !Norm     .norm>  ...     sbrkr<         .Gd
# 4        .CRAWFOR       NORm      NORM:  ...    \tSbrkr         Gd<
# 5       ?NoRIdge>   ...NORM<      Norm;  ...    \tSbrkr         GD;
# ...           ...        ...        ...  ...        ...         ...
# 1456 jutgilbert: Norm? NORM ... >sbrkr .ta
# 1457 ...Nvames NORM... yutnorm ... SBRKR TA!
# 1458    >CRAWfoR<       Norm    Norm...  ...     Sbrkr;         !Gd
# 1459        names       norm    \tnorm.  ...   \tFUseA:         Gd!
# 1460    \tEdwards    !NORM\t      norm?  ...    ;SBRKR?        ;ta:
#
# Functional GarageType GarageFinish GarageQual GarageCond PavedDrive  \
# Id
# 1 TYPE AttChd< .RFn TA\t \tTA< y?
# 2 ;TYP Attchd> RFn\t \tTa >TA\t ;Y!
# 3 TyP... Attchd; ;RFN \tTA... TA Y
# 4 !TYPE DETCHD... UNF? Take; ;Take .Y
# 5 <Typ> Attchd\t !rfn> TA\t Ta \tY>
# ...         ...        ...          ...        ...        ...        ...
# 1456 !TYP ;Attchd :RFn TA< :Ta Y;
# 1457      MIn1?    ATTCHD<         :unf       >Ta>        ?TA       >Y\t
# 1458 :TyP AttChD< ?Rfn >TA :TA: .Y
# 1459 TYPE attchd. Unf : Take; \tTA ...Y
# 1460 type: .ATTCHD FIn >ta? \tta< >y...
#
# SaleType SaleCondition
# Id
# 1         wd      \tNormal?
# 2         Wd        Normal.
# 3         WD;        NORMAL
# 4wd. ABNORMAL\t
# 5        ?WD!       NoRmAl>
# ...       ...           ...
# 1456      Wd?     normal...
# 1457      Wd;     \tNormal;
# 1458     >wd!      :NORMAL;
# 1459     <WD!       :normal
# 1460      Wd;       ;NORMAL
#
# [1338 rows x 38 columns]
# ```

# %%
pd_dirty_data=dirty_data.copy()
pd_dirty_data

# %%
#Начало вашего кода

#Конец вашего кода
print(pd_dirty_data)

# %% [markdown]
# ### Ожидаемый результат:
#
# ```
# MSZoning Street LotShape LandContour Utilities LotConfig LandSlope  \
# Id
# 1          RL   PAVE      REG         LVL    ALLPUB    INSIDE       GTL
# 2          RL   PAVE      REG         LVL    ALLPUB       FR2       GTL
# 3          RL   PAVE      IR1         LVL    ALLPUB    INSIDE       GTL
# 4          RL   PAVE      IR1         LVL    ALLPUB    CORNER       GTL
# 5          RL   PAVE      IR1         LVL    ALLPUB       FR2       GTL
# ...       ...    ...      ...         ...       ...       ...       ...
# 1456       RL   PAVE      REG         LVL    ALLPUB    INSIDE       GTL
# 1457       RL   PAVE      REG         LVL    ALLPUB    INSIDE       GTL
# 1458       RL   PAVE      REG         LVL    ALLPUB    INSIDE       GTL
# 1459       RL   PAVE      REG         LVL    ALLPUB    INSIDE       GTL
# 1460       RL   PAVE      REG         LVL    ALLPUB    INSIDE       GTL
#
# Neighborhood Condition1 Condition2  ... Electrical KitchenQual  \
# Id                                       ...
# 1         COLLGCR       NORM       NORM  ...      SBRKR          GD
# 2 VEENKER FEEDER NORM ... SBRKR TA
# 3         COLLGCR       NORM       NORM  ...      SBRKR          GD
# 4 CRAWFORD NORM NORM ... BRKR GD
# 5         NORIDGE       NORM       NORM  ...      SBRKR          GD
# ...           ...        ...        ...  ...        ...         ...
# 1456      GILBERT       NORM       NORM  ...      SBRKR          TA
# 1457 NWAMES NORM NORM ... SBRKR TA
# 1458      CRAWFOR       NORM       NORM  ...      SBRKR          GD
# 1459        NAMES       NORM       NORM  ...      FUSEA          GD
# 1460      EDWARDS       NORM       NORM  ...      SBRKR          TA
#
# Functional GarageType GarageFinish GarageQual GarageCond PavedDrive  \
# Id
# 1 ATTACHD TYPE RFN TA TA Y
# 2 ATTACHD TYPE RFN TA TA Y
# 3 ATTACHD TYPE RFN TA TA Y
# 4 TYP DETCHD UNF TA TA Y
# 5 ATTACHD TYPE RFN TA TA Y
# ...         ...        ...          ...        ...        ...        ...
# 1456 ATTACHD TYPE RFN TA TA Y
# 1457 MIN1 ATTCHD UNF TA TA Y
# 1458 ATTACHD TYPE RFN TA TA Y
# 1459 TYPE ATTCHD UNF TA TA Y
# 1460 TYPE ATTCHD FIN TA TA Y
#
# SaleType SaleCondition
# Id
# 1          WD        NORMAL
# 2          WD        NORMAL
# 3          WD        NORMAL
# 4WD ABNORMAL
# 5          WD        NORMAL
# ...       ...           ...
# 1456       WD        NORMAL
# 1457       WD        NORMAL
# 1458       WD        NORMAL
# 1459       WD        NORMAL
# 1460       WD        NORMAL
#
# [1338 rows x 38 columns]
# ```

# %% [markdown]
# ### Шаг 4
#
#
# После очистки ```pd_dirty_data```, сравните его с ``` pd_data```. Нужно ли внести некоторые изменения в ```pd_data``` или / и ```pd_dirty_data```, чтобы сделать честное сравнение? Реализуйте функцию ```compare_dataframes(pd_data, pd_dirty_data)```, которая будет сравнивать входные данные ```DataFrames```.

# %%
#Начало вашего кода

#Конец вашего кода
print(compare_dataframes(pd_data, pd_dirty_data))

# %% [markdown]
# ### Ожидаемый результат:
#
# ```
# (%) same
# MSZoning       100.000000
# Street         100.000000
# LotShape 100.000000
# LandContour    100.000000
# Utilities      100.000000
# LotConfig      100.000000
# LandSlope      100.000000
# Neighborhood   100.000000
# Condition1 100.000000
# Condition2     100.000000
# BldgType 100.000000
# HouseStyle      87.967115
# RoofStyle      100.000000
# RoofMatl       100.000000
# Exterior1st    100.000000
# Exterior2nd    100.000000
# MasVnrType     100.000000
# ExterQual      100.000000
# ExterCond      100.000000
# Foundation     100.000000
# BsmtQual       100.000000
# BsmtCond       100.000000
# BsmtExposure   100.000000
# BsmtFinType1   100.000000
# BsmtFinType2   100.000000
# Heating        100.000000
# HeatingQC      100.000000
# CentralAir     100.000000
# Electrical     100.000000
# KitchenQual    100.000000
# Functional     100.000000
# GarageType 100.000000
# GarageFinish   100.000000
# GarageQual     100.000000
# GarageCond     100.000000
# PavedDrive     100.000000
# SaleType       100.000000
# SaleCondition 100.000000
# ```

# %% [markdown]
# # Прекрасная работа!
